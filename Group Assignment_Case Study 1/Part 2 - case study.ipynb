# %%
import pandas as pd
data = pd.read_csv(r'D:\python files and libraries\Tayko.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c4b29eddc57c> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv(r'D:\python files and libraries\Tayko.csv')
#       3 data.head()
#
# ...

# %%
import pandas as pd
import os

   # Print the current working directory
print(os.getcwd())
# Out:
# /content

# %%
os.chdir(r'D:\python files and libraries')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-222ce9cd8b24> in <cell line: 0>()
# ----> 1 os.chdir(r'D:/python files and libraries')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/python files and libraries'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd9832d2-e6c3-4dc6-84fd-138781c891d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd9832d2-e6c3-4dc6-84fd-138781c891d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('Tayko.csv')
data.head()
# Out:
#    sequence_number  US  source_a  source_c  source_b  source_d  source_e  \
# 0                1   1         0         0         1         0         0
# 1                2   1         0         0         0         0         1
# 2                3   1         0         0         0         0         0
# 3                4   1         0         1         0         0         0
# 4                5   1         0         1         0         0         0
#
#    source_m  source_o  source_h  ...  source_x  source_w  Freq  \
# 0         0         0         0  ...         0         0     2
# 1         0         0         0  ...         0         0     0
# 2         0         0         0  ...         0         0     2
# 3         0         0         0  ...         0         0     1
# 4         0         0         0  ...         0         0     1
#
#    last_update_days_ago  1st_update_days_ago  Web order  Gender=male  \
# 0                  3662                 3662          1            0
# ...

# %%
# prompt: load and clean customer demographic and behavioural data

import pandas as pd
import io

# Upload the file from your local machine
from google.colab import files
uploaded = files.upload()

# Read the CSV data into a pandas DataFrame
data = pd.read_csv(io.BytesIO(uploaded['Tayko.csv'])) # Replace 'Tayko.csv' with your actual file name if different

# Data Cleaning
# 1. Handle Missing Values
# Check for missing values
print(data.isnull().sum())

# Decide how to handle missing values (e.g., imputation, removal)
# Example: Fill missing values in the 'age' column with the mean age
# data['age'].fillna(data['age'].mean(), inplace=True)

# 2. Remove duplicates
data.drop_duplicates(inplace=True)

# 3. Data type conversions
# Example: Convert a column to datetime format
# data['date_column'] = pd.to_datetime(data['date_column'])

# 4. Outlier detection and treatment
# Example using IQR method:
# Q1 = data['numerical_column'].quantile(0.25)
# Q3 = data['numerical_column'].quantile(0.75)
# IQR = Q3 - Q1
# upper_bound = Q3 + 1.5 * IQR
# lower_bound = Q1 - 1.5 * IQR
# data = data[(data['numerical_column'] >= lower_bound) & (data['numerical_column'] <= upper_bound)]


# 5. Inconsistent data entries
# Example: Standardize categorical data (e.g., gender)
# data['gender'] = data['gender'].str.lower() # Convert all values to lower case
# data['gender'] = data['gender'].replace({'male': 'M', 'female': 'F'}) # Replace with consistent values


# 6. Irrelevant columns (if any)
# Example: Remove a column named 'unnecessary_column'
# data.drop('unnecessary_column', axis=1, inplace=True)

# Display the cleaned data
data.head()
print(data.info())
# Out:
#      <input type="file" id="files-a5464dce-d685-40f5-8732-565c52e3d556" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5464dce-d685-40f5-8732-565c52e3d556">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(data.isnull().sum())
# Out:
# sequence_number         0
# US                      0
# source_a                0
# source_c                0
# source_b                0
# source_d                0
# source_e                0
# source_m                0
# source_o                0
# source_h                0
# source_r                0
# source_s                0
# source_t                0
# source_u                0
# source_p                0
# source_x                0
# source_w                0
# Freq                    0
# last_update_days_ago    0
# 1st_update_days_ago     0
# Web order               0
# Gender=male             0
# Address_is_res          0
# Purchase                0
# Spending                0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.head()
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sequence_number       2000 non-null   int64
#  1   US                    2000 non-null   int64
#  2   source_a              2000 non-null   int64
#  3   source_c              2000 non-null   int64
#  4   source_b              2000 non-null   int64
#  5   source_d              2000 non-null   int64
#  6   source_e              2000 non-null   int64
#  7   source_m              2000 non-null   int64
#  8   source_o              2000 non-null   int64
#  9   source_h              2000 non-null   int64
#  10  source_r              2000 non-null   int64
#  11  source_s              2000 non-null   int64
#  12  source_t              2000 non-null   int64
#  13  source_u              2000 non-null   int64
#  14  source_p              2000 non-null   int64
# ...
